# %% [markdown]
# <a href="https://colab.research.google.com/github/mukdame/IntroTensorflow/blob/master/HelloWorldOfTensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Create the vectors X and Y
x = np.array(range(10))

y = 5-x
# Create the plot
plt.plot(x,y,label='x+y=5')

y = (12-3*x)/2
plt.plot(x, y,label='3x+2y=12')

# Show the plot
plt.show()

# %% [markdown]
# Introduction Tensorflow
#
# **The ‘Hello World’ of neural networks**

# %%
from tensorflow.keras import layers
from tensorflow import keras 
import tensorflow as tf
import numpy as np

# %%
xs = np.array([-1, 0, 1, 2, 3, 4, 5], dtype=int)
ys = np.array([-3, -1, 1, 3, 5, 7, 9], dtype=int)
# relationship between x and y is y = 2x-1

# %%
#NN unit:1 neuron, Dense: 1 layer
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer="sgd", loss="mean_squared_error")

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Train on 7 samples
# Epoch 1/500
# 7/7 [==============================] - 1s 102ms/sample - loss: 69.4922
# Epoch 2/500
# 7/7 [==============================] - 0s 749us/sample - loss: 48.2395
# Epoch 3/500
# 7/7 [==============================] - 0s 301us/sample - loss: 33.6123
# Epoch 4/500
# 7/7 [==============================] - 0s 357us/sample - loss: 23.5427
# Epoch 5/500
# 7/7 [==============================] - 0s 458us/sample - loss: 16.6083
# Epoch 6/500
# 7/7 [==============================] - 0s 474us/sample - loss: 11.8306
# Epoch 7/500
# 7/7 [==============================] - 0s 563us/sample - loss: 8.5366
# Epoch 8/500
# 7/7 [==============================] - 0s 246us/sample - loss: 6.2634
# Epoch 9/500
# 7/7 [==============================] - 0s 466us/sample - loss: 4.6923
# Epoch 10/500
# 7/7 [==============================] - 0s 408us/sample - loss: 3.6045
# Epoch 11/500
# 7/7 [==============================] - 0s 552us/sample - loss: 2.8492
# Epoch 12/500
# ...

# %%
print(model.predict([10]))
# Out:
# [[18.974308]]
